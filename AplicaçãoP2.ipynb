# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiasouza74-cpu/FundamentosComputacionais/blob/main/Aplica%C3%A7%C3%A3oP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/leticiasouza74-cpu/FundamentosComputacionais.git -qq
# Out:
# fatal: destination path 'FundamentosComputacionais' already exists and is not an empty directory.

# %%
! ls FundamentosComputacionais
# Out:
# Aula_FC_07_04.ipynb			Prova_1_Fund_Computacionais.ipynb
# CSTR_série_P2.ipynb			Prova2funcaoatualizada.ipynb
# FC_16_04_aplicando_função_básica.ipynb	Prova2funcaoatz.ipynb
# FC_16_04.ipynb				Prova2funcao.ipynb
# Funcao_CSTR.ipynb			Secador.py
# P2funcao.ipynb				Tanque_de_mistura_Aula_FCO_14_05.ipynb

# %%
from Prova2funcaoatualizada import (Vmaxt, dSdt, simula, param)
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_19908/2839391600.py in <cell line: 0>()
# ----> 1 from Prova2funcaoatualizada import (Vmaxt, dSdt, simula, param)
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'Prova2funcaoatualizada'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

T = [298.15,308.15, 318.15]
S0 = 100

t = np.linspace(0, 30, 1000)

t, S = simula(t=t, S0=100, param = param, T)


plt.plot(t, S)
plt.xlabel("Tempo [h]")
plt.ylabel("Concentração [mg/L]")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19908/3577744350.py in <cell line: 0>()
#       6 t = np.linspace(0, 30, 1000)
#       7
# ----> 8 t, S = simula(t=t, S0=100, param = param, T=298.15)
#       9
#      10
#
# NameError: name 'param' is not defined

# %%
import matplotlib.pyplot as plt
